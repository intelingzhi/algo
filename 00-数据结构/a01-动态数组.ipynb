# %%
# 严格来说，Python 没有静态数组的定义方式
# 我们暂且使用列表模拟静态数组

arr = [0] * 10  # 定义一个长度为10的静态数组，初始值为0

# %%
# 动态数组
arr = []
arr.append(1)  # 在数组末尾添加元素1
arr.insert(0, 2)  # 在数组开头插入元素2
arr.pop()  # 删除并返回数组末尾的元素
arr
# Out:
# [2]
